# %%
from fyers_apiv3 import fyersModel
import pandas as pd
from fyers_apiv3.FyersWebsocket import data_ws
import datetime as dt
import time
import numpy as np
import math
from datetime import date

# %%
# login process

client_id = "VVCFTCB9Y7-100"
secret_key = "8U5LQ172V9"
redirect_uri = "https://trade.fyers.in/api-login/redirect-uri/index.html"
response_type = "code"
grant_type = "authorization_code"
emadata = pd.DataFrame()
session = fyersModel.SessionModel(
    client_id=client_id,
    secret_key=secret_key,
    redirect_uri=redirect_uri,
    response_type=response_type,
    grant_type=grant_type,
)

# %%
# Generate the auth code using the session model
response = session.generate_authcode()
# Print the auth code received in the response
print(response)

# uri = 'https://trade.fyers.in/api-login/redirect-uri/index.html?s=ok&code=200&auth_code=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....e_Uadk1I-kVke37pC2xgtnu6msqVJmkAq2IZ7Jve7nw&state=None'
# s1 = uri.split('auth_code=')
# auth=s1[1].split('&state')[0]
# Out:
# https://api-t1.fyers.in/api/v3/generate-authcode?client_id=VVCFTCB9Y7-100&redirect_uri=https%3A%2F%2Ftrade.fyers.in%2Fapi-login%2Fredirect-uri%2Findex.html&response_type=code&state=None

# %%
auth_code = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....saBS7-L3E5tc8Nls_9EKygx0WdNMqwmDdvUC1_vprwQ"

# %%
# print(auth)

# %%
# Set the authorization code in the session object
session.set_token(auth_code)
# Generate the access token using the authorization code
response = session.generate_token()
# Print the response, which should contain the access token and other details
print(response)
# Out:
# {'s': 'ok', 'code': 200, 'message': '', 'access_token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....-QtvwKfesnSaLydLV504OI3PJi4JbQ7O_5DDn36FPkw', 'refresh_token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....7kKHwnqx_BJNWSDebsZbUcR9aQquD1eT6CQ7tMcyESs'}

# %%
df = pd.DataFrame()
df = response
tk = df["access_token"]
# Initialize the FyersModel instance with your client_id, access_token, and enable async mode
fyers = fyersModel.FyersModel(
    client_id=client_id, is_async=False, token=tk, log_path=""
)

# %%
# variables
buypos = 0
sellpos = 0
stoploss = 0
entry = 0
bflag = 0
sflag = 0
spos = 0
bpos = 0
exit = 0
target = 0
cstrike = ""
pstrike = ""
row = -2
expiry = "NSE:BANKNIFTY24508"
sym = "NSE:NIFTYBANK-INDEX"
gain = 0
fmflag = 0
fimflag = 0
points = 0
emadata5 = pd.DataFrame()
emadata15 = pd.DataFrame()
date_from = "2024-04-03"
date_to = "2024-05-30"

# %%
print(emadata5)

# %%
# get data function
def getdata(sym, res, rfrom, rto):
    global emadata5, emadata15
    cdata = {
        "symbol": sym,
        "resolution": str(res),
        "date_format": "1",
        "range_from": rfrom,
        "range_to": rto,
        "cont_flag": "0",
    }

    response = fyers.history(data=cdata)
    data = pd.DataFrame.from_dict(response["candles"])
    cols = ["datetime", "open", "high", "low", "close", "volume"]
    data.columns = cols
    data["datetime"] = pd.to_datetime(data["datetime"], unit="s")
    data["datetime"] = (
        data["datetime"].dt.tz_localize("utc").dt.tz_convert("Asia/Kolkata")
    )
    data["datetime"] = data["datetime"].dt.tz_localize(None)
    data = data.set_index("datetime")
    data["ema"] = data["close"].ewm(span=5, min_periods=5).mean()
    if res == 5:
        emadata5 = data
    if res == 15:
        emadata15 = data

# %%
getdata(sym, 5, date_from, date_to)
emadata5["close"].iloc[row]
emadata15["close"].iloc[row]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 3
#       1 getdata(sym, 5, date_from, date_to)
#       2 emadata5["close"].iloc[row]
# ----> 3 emadata15["close"].iloc[row]
#
# File c:\Users\Shiva Kumar G\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File c:\Users\Shiva Kumar G\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'close'

# %%
# on message function
def onmessage(message):
    # symb = message['symbol']
    # ltp = message['ltp']
    # print(message)
    t = time.localtime()
    cmin = time.strftime("%M", t)
    csec = time.strftime("%S", t)
    global buypos, sellpos, stoploss, exit, pstrike, cstrike, target, bflag, sflag, sym, fmflag, fimflag, bpos, spos, gain, entry, points
    if int(cmin) % 5 == 0 and int(csec) >= 1 and fmflag == 0:
        print("5 ema data updated")
        getdata(sym, 5, date_from, date_to)
        fmflag = 1
        if spos == 0:
            sflag = 0
    if int(cmin) % 5 != 0 and fmflag == 1:
        fmflag = 0
    if int(cmin) % 15 == 0 and int(csec) >= 1 and fimflag == 0:
        print("15 ema data updated")
        getdata(sym, 15, date_from, date_to)
        fimflag = 1
        if bpos == 0:
            bflag = 0
    if int(cmin) % 15 != 0 and fimflag == 1:
        fimflag = 0
    #     ema = emadata['ema'].iloc[-2]
    #     l =  emadata['low'].iloc[-2]
    print(f"{message}")

    if (
        emadata5["close"].iloc[row] > emadata5["ema"].iloc[row]
        and emadata5["high"].iloc[row] > emadata5["ema"].iloc[row]
        and emadata5["open"].iloc[row] > emadata5["ema"].iloc[row]
        and emadata5["low"].iloc[row] > emadata5["ema"].iloc[row]
        and message["ltp"] < emadata5["low"].iloc[row]
    ):
        ltp = message["ltp"]
        sp = int(round(ltp, -2))

        if spos == 0 and sflag == 0:
            spos = sflag = 1
            entry = message["ltp"]
            stoploss = emadata5["high"].iloc[row]
            target = message["ltp"] - (
                (emadata5["high"].iloc[row] - emadata5["low"].iloc[row]) * 2
            )
            print("sell entry")
            pstrike = expiry + str(sp) + "PE"
            # data = {
            #     "symbol": str(pstrike),
            #     "qty":15,
            #     "type":2,
            #     "side":1,
            #     "productType":"MARGIN",
            #     "limitPrice":0,
            #     "stopPrice":0,
            #     "validity":"DAY",
            #     "disclosedQty":0,
            #     "offlineOrder":False,
            #     }
            print(f"entry {pstrike}")
            # response = fyers.place_order(data=data)

    if (
        emadata15["close"].iloc[row] < emadata15["ema"].iloc[row]
        and emadata15["high"].iloc[row] < emadata15["ema"].iloc[row]
        and emadata15["open"].iloc[row] < emadata15["ema"].iloc[row]
        and emadata15["low"].iloc[row] < emadata15["ema"].iloc[row]
        and message["ltp"] > emadata15["high"].iloc[row]
    ):
        ltp = message["ltp"]
        sp = int(round(ltp, -2))

        if bpos == 0 and bflag == 0:
            bpos = bflag = 1
            entry = message["ltp"]
            stoploss = emadata15["low"].iloc[row]
            target = message["ltp"] + (
                (emadata15["high"].iloc[row] - emadata15["low"].iloc[row]) * 2
            )
            print("buy entry")
            cstrike = expiry + str(sp) + "CE"
            # data = {
            #     "symbol": str(cstrike),
            #     "qty":15,
            #     "type":2,
            #     "side":1,
            #     "productType":"MARGIN",
            #     "limitPrice":0,
            #     "stopPrice":0,
            #     "validity":"DAY",
            #     "disclosedQty":0,
            #     "offlineOrder":False,
            #     }
            print(f"entry {cstrike}")
            # response = fyers.place_order(data=data)
    if spos == 1 and message["ltp"] > stoploss:
        gain += entry - stoploss
        spos = 0
        stoploss = 0
        entry = 0
        target = 0
        # data = {
        #     "symbol": str(pstrike),
        #     "qty":15,
        #     "type":2,
        #     "side":-1,
        #     "productType":"MARGIN",
        #     "limitPrice":0,
        #     "stopPrice":0,
        #     "validity":"DAY",
        #     "disclosedQty":0,
        #     "offlineOrder":False,
        #     }
        print(f"entry {pstrike}")
        # response = fyers.place_order(data=data)
    if spos == 1 and message["ltp"] <= target:
        if points <= 50:
            points = 50
        stoploss = stoploss + points
        target = target + points
        # stoploss = emadata5['high'].iloc[-5] # stoploss based on 5 min high, either points code mentioned above, or this, or hiken ashi
        # gain += entry - target
        # spos = 0
        # stoploss = 0
        # entry = 0
        # target = 0
        # # data = {
        # #     "symbol": str(pstrike),
        # #     "qty":15,
        # #     "type":2,
        # #     "side":-1,
        # #     "productType":"MARGIN",
        # #     "limitPrice":0,
        # #     "stopPrice":0,
        # #     "validity":"DAY",
        # #     "disclosedQty":0,
        # #     "offlineOrder":False,
        # #     }
        print(f"entry {pstrike}")
        # # response = fyers.place_order(data=data)
    if bpos == 1 and message["ltp"] < stoploss:
        gain += stoploss - entry
        bpos = 0
        stoploss = 0
        entry = 0
        target = 0
        # data = {
        #     "symbol": str(cstrike),
        #     "qty":15,
        #     "type":2,
        #     "side":-1,
        #     "productType":"MARGIN",
        #     "limitPrice":0,
        #     "stopPrice":0,
        #     "validity":"DAY",
        #     "disclosedQty":0,
        #     "offlineOrder":False,
        #     }
        print(f"entry {cstrike}")
        # response = fyers.place_order(data=data)
    if bpos == 1 and message["ltp"] >= target:
        gain += target - entry
        bpos = 0
        stoploss = 0
        entry = 0
        target = 0
        # data = {
        #     "symbol": str(cstrike),
        #     "qty":15,
        #     "type":2,
        #     "side":-1,
        #     "productType":"MARGIN",
        #     "limitPrice":0,
        #     "stopPrice":0,
        #     "validity":"DAY",
        #     "disclosedQty":0,
        #     "offlineOrder":False,
        #     }
        print(f"entry {cstrike}")
        # response = fyers.place_order(data=data)

# %%
def onerror(message):
    print("Error:", message)

# %%
def onclose(message):
    print("Connection closed:", message)

# %%
def onopen():
    data_type = "SymbolUpdate"
    symbols = [sym]
    fyersdata.subscribe(symbols=symbols, data_type=data_type)
    fyersdata.keep_running()

# %%
# Replace the sample access token with your actual access token obtained from Fyers
access_token = client_id + ":" + tk
# Create a FyersDataSocket instance with the provided parameters
fyersdata = data_ws.FyersDataSocket(
    access_token=access_token,  # Access token in the format "appid:accesstoken"
    log_path="",  # Path to save logs. Leave empty to auto-create logs in the current directory.
    litemode=True,  # Lite mode disabled. Set to True if you want a lite response.
    write_to_file=False,  # Save response in a log file instead of printing it.
    reconnect=True,  # Enable auto-reconnection to WebSocket on disconnection.
    on_connect=onopen,  # Callback function to subscribe to data upon connection.
    on_close=onclose,  # Callback function to handle WebSocket connection close events.
    on_error=onerror,  # Callback function to handle WebSocket errors.
    on_message=onmessage,  # Callback function to handle incoming messages from the WebSocket.
)
# Establish a connection to the Fyers WebSocket
fyersdata.connect()
# Out:
# 0 0
# {'type': 'cn', 'code': 200, 'message': 'Authentication done', 's': 'ok'}
# Error: KeyError: The key 'close' is missing in the response.
# {'type': 'lit', 'code': 200, 'message': 'Lite Mode On', 's': 'ok'}
# Error: KeyError: The key 'close' is missing in the response.
# {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47719.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47720.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47722.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47721.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47721.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47721.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47722.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47723.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47721.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47718.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47718.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47721.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47720.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47718.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47720.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47719.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47716.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47715.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47716.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47714.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47714.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47714.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47717.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47718.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47717.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47715.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47713.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47715.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47717.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47719.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47718.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47720.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47719.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47717.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47717.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47718.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47714.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47713.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47716.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47716.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47720.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47724.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47725.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47724.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47724.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47723.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47725.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47725.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47728.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47727.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47730.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47730.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47730.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47729.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47728.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47730.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47728.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47728.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47730.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47728.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47730.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47731.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47731.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47730.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47730.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47733.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47734.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47734.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47746.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47747.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47746.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47747.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47743.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47744.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47749.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47749.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47753.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47751.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47753.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47752.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47752.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47751.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47753.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47751.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47753.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47754.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47754.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47754.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47754.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47750.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47749.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47750.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47751.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47750.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47751.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47750.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47751.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47750.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47749.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47754.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47753.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47754.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47752.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47753.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47752.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47749.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47745.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47746.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47734.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47740.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47745.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47744.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47745.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47740.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47745.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47750.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47752.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47754.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47753.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47752.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47753.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47755.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47756.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47751.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47756.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47754.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47754.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47759.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47753.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47753.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47752.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47754.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47753.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47754.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47751.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47757.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47757.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47758.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47754.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47753.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47758.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47759.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47755.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47754.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47755.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47753.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47749.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47755.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47754.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47756.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47756.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47755.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47758.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47757.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47759.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47760.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47754.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47757.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47758.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47758.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47756.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47757.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47759.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47761.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47756.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47761.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47760.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47761.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47762.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47761.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47761.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47759.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47759.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47761.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47759.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47761.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47762.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47762.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47760.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47757.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47758.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47755.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47758.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47759.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47761.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47760.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47760.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47759.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47758.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47758.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47759.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47759.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47756.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47759.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47759.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47759.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47764.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47764.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47764.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47764.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47763.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47764.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47767.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47768.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47767.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47768.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47762.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47767.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47767.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47768.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47771.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47772.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47773.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47774.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47774.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47772.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47771.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47771.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47772.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47772.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# 5 ema data updated
# {'ltp': 47773.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47772.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47773.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47772.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47773.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47773.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47772.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47770.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47774.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47771.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47770.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47775.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47769.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47769.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47774.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47773.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47771.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47772.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47772.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47775.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47771.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47771.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47772.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47773.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47771.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47771.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47774.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47771.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47772.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47769.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47772.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47771.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47762.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47764.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47760.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47760.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47767.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47767.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47763.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47768.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47768.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47767.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47764.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47767.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47767.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47767.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47764.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47764.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47767.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47767.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47768.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47770.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47770.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47772.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47770.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47770.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47768.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47763.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47762.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47764.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47762.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47760.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47762.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47761.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47762.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47760.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47759.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47761.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47761.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47761.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47759.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47760.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47764.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47763.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47764.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47769.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47769.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47768.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47765.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47768.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47767.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47767.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47764.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47767.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47767.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47768.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47766.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47767.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47768.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47770.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47770.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47770.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47772.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47773.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47775.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47774.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47776.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47773.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47775.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47770.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47774.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47777.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47772.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47774.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47775.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47775.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47774.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47775.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47772.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47774.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47774.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47776.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47773.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# {'ltp': 47772.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# Error: KeyError: The key 'close' is missing in the response.
# ...
# {'ltp': 47432.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47433.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47427.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47432.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47433.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47434.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47433.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47433.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47427.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47425.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47427.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47431.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47431.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47436.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47436.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47433.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47438.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47438.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47437.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47438.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47434.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47433.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47433.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47433.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47434.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47433.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47431.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47426.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47432.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47431.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47432.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47433.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47433.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47433.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47427.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47426.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47424.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47427.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47427.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47425.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47422.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47426.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47427.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47426.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47424.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47423.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47422.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47422.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47422.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47418.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47423.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47421.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47421.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47420.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47419.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47418.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47418.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47414.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47419.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47422.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47422.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47423.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47423.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47424.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47422.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47420.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47423.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47423.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47425.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47431.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47432.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47435.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47437.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47435.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47434.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47435.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47436.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47437.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47438.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47435.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47438.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47438.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47436.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47435.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47439.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47436.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47435.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47433.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47433.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47435.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47433.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47434.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47436.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47433.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47434.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47434.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47432.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47425.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47432.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47432.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47431.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47431.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47427.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47427.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47427.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47426.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47427.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47424.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47425.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47426.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47426.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47427.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47431.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47431.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47426.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47427.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47425.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47425.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47424.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47426.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47427.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47431.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47431.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47431.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47432.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47431.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47433.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47432.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47431.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47426.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# 5 ema data updated
# 15 ema data updated
# {'ltp': 47426.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47425.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47424.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47423.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47421.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47420.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47422.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47422.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47422.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47424.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47425.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47426.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47424.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47425.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47423.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47423.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47423.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47424.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47424.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47424.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47426.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47426.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47427.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47426.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47425.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47431.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47431.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47432.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47426.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47431.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47430.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47428.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47429.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47425.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47426.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47426.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47426.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47421.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47422.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47416.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47418.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47419.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# {'ltp': 47418.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}

# %%
print(gain)
# Out:
# 0

# %%
fyersdata.disconnect()

# %%
print(f"entry {pstrike}")
print(f"entry {cstrike}")
# Out:
# entry
# entry
