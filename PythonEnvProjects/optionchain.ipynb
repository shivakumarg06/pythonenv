# %%
import credentials as cd
from fyers_apiv3 import fyersModel
import pandas as pd



from fyers_apiv3.FyersWebsocket import data_ws
import datetime as dt
import time



import numpy as np


import math
from datetime import date

# %%
# Reading the access token from the file
with open("access.txt", "r") as a:
    access_token = a.read()
client_id = cd.client_id
# Initialize the FyersModel instance with your client_id, access_token, and enable async mode
fyers = fyersModel.FyersModel(
    client_id=client_id, is_async=False, token=access_token, log_path=""
)

# %%
# Fetching the historical data for Nifty 50 index for 5 minutes interval for the month of May 2024 using the history API endpoint of Fyers API
data = {
    "symbol": "NSE:NIFTYBANK-INDEX",
    "resolution": "5",
    "date_format": "1",
    "range_from": "2024-05-01",
    "range_to": "2024-05-30",
    "cont_flag": "1",
}


response = fyers.history(data=data)
# print(response)
data = response["candles"]
df = pd.DataFrame(data)
# Converting the UNIX timestamp to datetime format and setting the date column as the index of the dataframe and saving the data to a CSV file
df.columns = ["date", "open", "high", "low", "close", "volume"]


df["date"] = pd.to_datetime(df["date"], unit="s")
df.date = df.date.dt.tz_localize("UTC").dt.tz_convert("Asia/Kolkata")
print(df)
df["date"] = df["date"].dt.tz_localize(None)
df = df.set_index("date")

# # Resample the data to business day frequency, using forward fill to handle the missing values
# df = df.resample("B").ffill()

print(df)
df.to_csv("data.csv")
print(dt.datetime.now())
# Out:
#                           date      open      high       low     close  volume
# 0    2024-05-02 09:15:00+05:30  49262.00  49521.30  49221.45  49465.00       0
# 1    2024-05-02 09:20:00+05:30  49468.65  49468.65  49370.60  49437.95       0
# 2    2024-05-02 09:25:00+05:30  49439.10  49452.10  49377.15  49411.45       0
# 3    2024-05-02 09:30:00+05:30  49410.20  49477.70  49382.50  49413.20       0
# 4    2024-05-02 09:35:00+05:30  49414.00  49461.80  49379.65  49391.60       0
# ...                        ...       ...       ...       ...       ...     ...
# 1141 2024-05-23 15:05:00+05:30  48744.90  48816.65  48734.90  48810.55       0
# 1142 2024-05-23 15:10:00+05:30  48811.15  48829.70  48791.10  48802.20       0
# 1143 2024-05-23 15:15:00+05:30  48804.40  48826.15  48770.20  48785.60       0
# 1144 2024-05-23 15:20:00+05:30  48784.55  48784.80  48749.80  48774.35       0
# 1145 2024-05-23 15:25:00+05:30  48775.65  48779.25  48731.50  48737.05       0
#
# [1146 rows x 6 columns]
#                          open      high       low     close  volume
# date
# 2024-05-02 09:15:00  49262.00  49521.30  49221.45  49465.00       0
# 2024-05-02 09:20:00  49468.65  49468.65  49370.60  49437.95       0
# 2024-05-02 09:25:00  49439.10  49452.10  49377.15  49411.45       0
# 2024-05-02 09:30:00  49410.20  49477.70  49382.50  49413.20       0
# 2024-05-02 09:35:00  49414.00  49461.80  49379.65  49391.60       0
# ...                       ...       ...       ...       ...     ...
# 2024-05-23 15:05:00  48744.90  48816.65  48734.90  48810.55       0
# 2024-05-23 15:10:00  48811.15  48829.70  48791.10  48802.20       0
# 2024-05-23 15:15:00  48804.40  48826.15  48770.20  48785.60       0
# 2024-05-23 15:20:00  48784.55  48784.80  48749.80  48774.35       0
# 2024-05-23 15:25:00  48775.65  48779.25  48731.50  48737.05       0
#
# [1146 rows x 5 columns]
# 2024-05-24 09:12:01.405826

# %%
# variables
buypos = 0
sellpos = 0
stoploss = 0
entry = 0
bflag = 0
sflag = 0
spos = 0
bpos = 0
exit = 0
target = 0
cstrike = ""
pstrike = ""
row = -2
expiry = "NSE:BANKNIFTY24508"
sym = "NSE:NIFTYBANK-INDEX"
gain = 0
fmflag = 0
fimflag = 0
points = 0
emadata5 = pd.DataFrame()
emadata15 = pd.DataFrame()
date_from = "2024-04-03"
date_to = "2024-05-30"

# %%
print(emadata5)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# get data function
def getdata(sym, res, rfrom, rto):
    global emadata5, emadata15
    cdata = {
        "symbol": sym,
        "resolution": str(res),
        "date_format": "1",
        "range_from": rfrom,
        "range_to": rto,
        "cont_flag": "0",
    }

    response = fyers.history(data=cdata)
    data = pd.DataFrame.from_dict(response["candles"])
    cols = ["datetime", "open", "high", "low", "close", "volume"]
    data.columns = cols
    data["datetime"] = pd.to_datetime(data["datetime"], unit="s")
    data["datetime"] = (
        data["datetime"].dt.tz_localize("utc").dt.tz_convert("Asia/Kolkata")
    )
    data["datetime"] = data["datetime"].dt.tz_localize(None)
    data = data.set_index("datetime")
    data["ema"] = data["close"].ewm(span=5, min_periods=5).mean()
    if res == 5:
        emadata5 = data
    if res == 15:
        emadata15 = data

# %%
getdata(sym, 5, date_from, date_to)
emadata5["close"].iloc[row]
emadata15["close"].iloc[row]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 3
#       1 getdata(sym, 5, date_from, date_to)
#       2 emadata5["close"].iloc[row]
# ----> 3 emadata15["close"].iloc[row]
#
# File c:\Users\Shiva Kumar G\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File c:\Users\Shiva Kumar G\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'close'

# %%
# on message function
def onmessage(message):
    # symb = message['symbol']
    # ltp = message['ltp']
    # print(message)
    t = time.localtime()
    cmin = time.strftime("%M", t)
    csec = time.strftime("%S", t)
    global buypos, sellpos, stoploss, exit, pstrike, cstrike, target, bflag, sflag, sym, fmflag, fimflag, bpos, spos, gain, entry, points
    if int(cmin) % 5 == 0 and int(csec) >= 1 and fmflag == 0:
        print("5 ema data updated")
        getdata(sym, 5, date_from, date_to)
        fmflag = 1
        if spos == 0:
            sflag = 0
    if int(cmin) % 5 != 0 and fmflag == 1:
        fmflag = 0
    if int(cmin) % 15 == 0 and int(csec) >= 1 and fimflag == 0:
        print("15 ema data updated")
        getdata(sym, 15, date_from, date_to)
        fimflag = 1
        if bpos == 0:
            bflag = 0
    if int(cmin) % 15 != 0 and fimflag == 1:
        fimflag = 0
    #     ema = emadata['ema'].iloc[-2]
    #     l =  emadata['low'].iloc[-2]
    print(f"{message}")

    if (
        emadata5["close"].iloc[row] > emadata5["ema"].iloc[row]
        and emadata5["high"].iloc[row] > emadata5["ema"].iloc[row]
        and emadata5["open"].iloc[row] > emadata5["ema"].iloc[row]
        and emadata5["low"].iloc[row] > emadata5["ema"].iloc[row]
        and message["ltp"] < emadata5["low"].iloc[row]
    ):
        ltp = message["ltp"]
        sp = int(round(ltp, -2))

        if spos == 0 and sflag == 0:
            spos = sflag = 1
            entry = message["ltp"]
            stoploss = emadata5["high"].iloc[row]
            target = message["ltp"] - (
                (emadata5["high"].iloc[row] - emadata5["low"].iloc[row]) * 2
            )
            print("sell entry")
            pstrike = expiry + str(sp) + "PE"
            # data = {
            #     "symbol": str(pstrike),
            #     "qty":15,
            #     "type":2,
            #     "side":1,
            #     "productType":"MARGIN",
            #     "limitPrice":0,
            #     "stopPrice":0,
            #     "validity":"DAY",
            #     "disclosedQty":0,
            #     "offlineOrder":False,
            #     }
            print(f"entry {pstrike}")
            # response = fyers.place_order(data=data)

    if (
        emadata15["close"].iloc[row] < emadata15["ema"].iloc[row]
        and emadata15["high"].iloc[row] < emadata15["ema"].iloc[row]
        and emadata15["open"].iloc[row] < emadata15["ema"].iloc[row]
        and emadata15["low"].iloc[row] < emadata15["ema"].iloc[row]
        and message["ltp"] > emadata15["high"].iloc[row]
    ):
        ltp = message["ltp"]
        sp = int(round(ltp, -2))

        if bpos == 0 and bflag == 0:
            bpos = bflag = 1
            entry = message["ltp"]
            stoploss = emadata15["low"].iloc[row]
            target = message["ltp"] + (
                (emadata15["high"].iloc[row] - emadata15["low"].iloc[row]) * 2
            )
            print("buy entry")
            cstrike = expiry + str(sp) + "CE"
            # data = {
            #     "symbol": str(cstrike),
            #     "qty":15,
            #     "type":2,
            #     "side":1,
            #     "productType":"MARGIN",
            #     "limitPrice":0,
            #     "stopPrice":0,
            #     "validity":"DAY",
            #     "disclosedQty":0,
            #     "offlineOrder":False,
            #     }
            print(f"entry {cstrike}")
            # response = fyers.place_order(data=data)
    if spos == 1 and message["ltp"] > stoploss:
        gain += entry - stoploss
        spos = 0
        stoploss = 0
        entry = 0
        target = 0
        # data = {
        #     "symbol": str(pstrike),
        #     "qty":15,
        #     "type":2,
        #     "side":-1,
        #     "productType":"MARGIN",
        #     "limitPrice":0,
        #     "stopPrice":0,
        #     "validity":"DAY",
        #     "disclosedQty":0,
        #     "offlineOrder":False,
        #     }
        print(f"entry {pstrike}")
        # response = fyers.place_order(data=data)
    if spos == 1 and message["ltp"] <= target:
        if points <= 50:
            points = 50
        stoploss = stoploss + points
        target = target + points
        # stoploss = emadata5['high'].iloc[-5] # stoploss based on 5 min high, either points code mentioned above, or this, or hiken ashi
        # gain += entry - target
        # spos = 0
        # stoploss = 0
        # entry = 0
        # target = 0
        # # data = {
        # #     "symbol": str(pstrike),
        # #     "qty":15,
        # #     "type":2,
        # #     "side":-1,
        # #     "productType":"MARGIN",
        # #     "limitPrice":0,
        # #     "stopPrice":0,
        # #     "validity":"DAY",
        # #     "disclosedQty":0,
        # #     "offlineOrder":False,
        # #     }
        print(f"entry {pstrike}")
        # # response = fyers.place_order(data=data)
    if bpos == 1 and message["ltp"] < stoploss:
        gain += stoploss - entry
        bpos = 0
        stoploss = 0
        entry = 0
        target = 0
        # data = {
        #     "symbol": str(cstrike),
        #     "qty":15,
        #     "type":2,
        #     "side":-1,
        #     "productType":"MARGIN",
        #     "limitPrice":0,
        #     "stopPrice":0,
        #     "validity":"DAY",
        #     "disclosedQty":0,
        #     "offlineOrder":False,
        #     }
        print(f"entry {cstrike}")
        # response = fyers.place_order(data=data)
    if bpos == 1 and message["ltp"] >= target:
        gain += target - entry
        bpos = 0
        stoploss = 0
        entry = 0
        target = 0
        # data = {
        #     "symbol": str(cstrike),
        #     "qty":15,
        #     "type":2,
        #     "side":-1,
        #     "productType":"MARGIN",
        #     "limitPrice":0,
        #     "stopPrice":0,
        #     "validity":"DAY",
        #     "disclosedQty":0,
        #     "offlineOrder":False,
        #     }
        print(f"entry {cstrike}")
        # response = fyers.place_order(data=data)

# %%
def onerror(message):
    print("Error:", message)

# %%
def onclose(message):
    print("Connection closed:", message)

# %%
def onopen():
    data_type = "SymbolUpdate"
    symbols = [sym]
    fyersdata.subscribe(symbols=symbols, data_type=data_type)
    fyersdata.keep_running()

# %%
# Define the client_id
client_id = cd.client_id

# Reading the access token from the file
with open("access.txt", "r") as a:
    tk = a.read()

access_token = client_id + ":" + tk

# Create a FyersDataSocket instance with the provided parameters
fyersdata = data_ws.FyersDataSocket(
    access_token=access_token,  # Access token in the format "appid:accesstoken"
    log_path="",  # Path to save logs. Leave empty to auto-create logs in the current directory.
    litemode=True,  # Lite mode disabled. Set to True if you want a lite response.
    write_to_file=False,  # Save response in a log file instead of printing it.
    reconnect=True,  # Enable auto-reconnection to WebSocket on disconnection.
    on_connect=onopen,  # Callback function to subscribe to data upon connection.
    on_close=onclose,  # Callback function to handle WebSocket connection close events.
    on_error=onerror,  # Callback function to handle WebSocket errors.
    on_message=onmessage,  # Callback function to handle incoming messages from the WebSocket.
)

# Establish a connection to the Fyers WebSocket
fyersdata.connect()
# Out:
# 0 0
# {'type': 'cn', 'code': 200, 'message': 'Authentication done', 's': 'ok'}
# Error: KeyError: The key 'ltp' is missing in the response.
# {'type': 'lit', 'code': 200, 'message': 'Lite Mode On', 's': 'ok'}
# Error: KeyError: The key 'ltp' is missing in the response.
# {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'}
# Error: KeyError: The key 'ltp' is missing in the response.
# {'ltp': 48793.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48779.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48775.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48761.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48738.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48739.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48749.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48744.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48742.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48739.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48736.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48739.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48736.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48733.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48743.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# 5 ema data updated
# 15 ema data updated
# {'ltp': 48743.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48732.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48736.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48733.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48733.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48736.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48734.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48737.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48737.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48734.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48736.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48735.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48736.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48736.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48740.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48742.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48745.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48746.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48749.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48747.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48744.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48738.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48734.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48739.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48735.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48733.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48731.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48737.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48729.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48719.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48720.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48724.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48720.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48722.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48728.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48727.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48731.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48733.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48736.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48737.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48738.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48734.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48735.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48746.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48749.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48747.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48747.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48743.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48748.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48739.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48737.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48739.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48740.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48734.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48735.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48735.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48744.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48740.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48742.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48736.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48725.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48724.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE
# {'ltp': 48729.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'}
# entry NSE:BANKNIFTY2450848900PE

# %%
print(gain)
# Out:
# 0

# %%
fyersdata.disconnect()

# %%
print(f"entry {pstrike}")
print(f"entry {cstrike}")
